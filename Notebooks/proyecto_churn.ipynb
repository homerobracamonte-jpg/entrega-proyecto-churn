# %%
import pandas as pd

# 'nombre_del_archivo.csv' debe ser igual al nombre del archivo que subiste
df = pd.read_csv("data/telc_data.csv")

print("--- DIMENSIONES ---")
print(df.shape)

print("\n--- DATOS FALTANTES ---")
print(df.isnull().sum())
